# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("titanic_dataset.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
df.drop("Cabin",axis=1,inplace=True)

# %%
df.drop("Name",axis=1,inplace=True)

# %%
df.drop("Ticket",axis=1,inplace=True)

# %%
from sklearn.preprocessing import  OrdinalEncoder

# %%
embark = ["C","S","Q"]
emb = OrdinalEncoder()

# %%
df["Embarked"] =emb.fit_transform(df[["Embarked"]])

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  28.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#      Embarked
# 0         2.0
# 1         0.0
# 2         2.0
# 3         2.0
# 4         2.0
# ..        ...
# 886       2.0
# 887       2.0
# 888       2.0
# 889       0.0
# 890       1.0
#
# [891 rows x 9 columns]

# %%
from category_encoders import  BinaryEncoder
be = BinaryEncoder()
df["Sex"] = be.fit_transform(df[["Sex"]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\PRETHI~1\AppData\Local\Temp/ipykernel_24524/1383767110.py in <module>
#       1 from category_encoders import  BinaryEncoder
#       2 be = BinaryEncoder()
# ----> 3 df["Sex"] = be.fit_transform(df[["Sex"]])
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3644             self._setitem_array(key, value)
#    3645         elif isinstance(value, DataFrame):
# -> 3646             self._set_item_frame_value(key, value)
#    3647         elif (
#    3648             is_list_like(value)
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3774             len_cols = 1 if is_scalar(cols) else len(cols)
#    3775             if len_cols != len(value.columns):
# -> 3776                 raise ValueError("Columns must be same length as key")
#    3777
#    3778             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\PRETHI~1\AppData\Local\Temp/ipykernel_24524/4046822457.py in <module>
# ----> 1 df["Sex"] = be.fit_transform(df[["Sex"]])
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3644             self._setitem_array(key, value)
#    3645         elif isinstance(value, DataFrame):
# -> 3646             self._set_item_frame_value(key, value)
#    3647         elif (
#    3648             is_list_like(value)
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3774             len_cols = 1 if is_scalar(cols) else len(cols)
#    3775             if len_cols != len(value.columns):
# -> 3776                 raise ValueError("Columns must be same length as key")
#    3777
#    3778             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key

# %%
df["Sex"]=be.fit_transform(df[["Sex"]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\PRETHI~1\AppData\Local\Temp/ipykernel_24524/4149124049.py in <module>
# ----> 1 df["Sex"]=be.fit_transform(df[["Sex"]])
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3644             self._setitem_array(key, value)
#    3645         elif isinstance(value, DataFrame):
# -> 3646             self._set_item_frame_value(key, value)
#    3647         elif (
#    3648             is_list_like(value)
#
# ~\anaconda32021\envs\webapp\lib\site-packages\pandas\core\frame.py in _set_item_frame_value(self, key, value)
#    3774             len_cols = 1 if is_scalar(cols) else len(cols)
#    3775             if len_cols != len(value.columns):
# -> 3776                 raise ValueError("Columns must be same length as key")
#    3777
#    3778             # align right-hand-side columns if self.columns
#
# ValueError: Columns must be same length as key
